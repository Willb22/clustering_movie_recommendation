# %%
import pandas as pd

# %%
recom = pd.read_csv('./processed/recommendations.csv')
recom
# Out:
#        userId                                        recommended
# 0           8  ['Telstar:TheJoeMeekStory', 'PappaantePortas',...
# 1          20  ['Telstar:TheJoeMeekStory', 'PappaantePortas',...
# 2          43  ['Telstar:TheJoeMeekStory', 'PappaantePortas',...
# 3          47  ['Telstar:TheJoeMeekStory', 'PappaantePortas',...
# 4          49  ['Telstar:TheJoeMeekStory', 'PappaantePortas',...
# ...       ...                                                ...
# 35090  267730  ['SinCity:ADametoKillFor', 'BruceAlmighty', 'D...
# 35091  267737  ['SinCity:ADametoKillFor', 'BruceAlmighty', 'D...
# 35092  267779  ['SinCity:ADametoKillFor', 'BruceAlmighty', 'D...
# 35093  268565  ['SinCity:ADametoKillFor', 'BruceAlmighty', 'D...
# 35094  269760  ['SinCity:ADametoKillFor', 'BruceAlmighty', 'D...
#
# [35095 rows x 2 columns]

# %%
list(recom[recom['userId']==8]['recommended'])
# Out:
# ["['Telstar:TheJoeMeekStory', 'PappaantePortas', 'CasanovaBrown', 'TheStrangeLoveofMarthaIvers', 'Murder']"]

# %%
recom[recom['userId']==8]['recommended']
# Out:
# 0    ['Telstar:TheJoeMeekStory', 'PappaantePortas',...
# Name: recommended, dtype: object

# %%
best = pd.read_csv('./data_csv/best_movies_per_cluster.csv')
best
# Out:
#       index                     title  Kmeans_user_cluster  \
# 0         0              IntheBedroom                    5
# 1         1  WilburWantstoKillHimself                    5
# 2         3            TheInterpreter                    5
# 3         4            SnakesonaPlane                    5
# 4         9            PeopleonSunday                    5
# ...     ...                       ...                  ...
# 1795   1799               StripedTrip                    0
# 1796   1334                 Vollidiot                    0
# 1797   1525                    48Hrs.                    0
# 1798    725                   Sabrina                    0
# 1799   1776    Jnssonligansstrstakupp                    0
#
#       Kmeans_movies_cluster      mean       part  count  variance  \
# 0                         0  4.666667   0.340136      3  0.083333
# 1                         0  4.500000   0.566893      5  0.375000
# ...

# %%
ratings = pd.read_csv('./data_csv/ratings.csv')

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
ratings.groupby(['userId', 'movieId'])['rating'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-49c11ca5557b> in <module>()
# ----> 1 ratings.groupby(['userId', 'movieId'])['rating'].iloc[0]
#
# /home/will/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'iloc'
